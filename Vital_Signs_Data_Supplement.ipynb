# %% [markdown]
# <a href="https://colab.research.google.com/github/ejf78/cdc_vitalsigns/blob/master/Vital_Signs_Data_Supplement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vital Signs Data Supplement
#
# A notebook to grab additional data from BNIA's APIs. The plan is to grab all available indicators that I didn't previously pull, as well as grab the Baltimore City data for all indicators.

# %% [markdown]
# ## Set Up

# %%
# clone the github respository, so that we have all the necessary files 
# !git clone https://github.com/ejf78/cdc_vitalsigns.git
# Out:
# Cloning into 'cdc_vitalsigns'...
# remote: Enumerating objects: 180, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (159/159), done.
# remote: Total 180 (delta 90), reused 69 (delta 21), pack-reused 0
# Receiving objects: 100% (180/180), 75.63 MiB | 10.82 MiB/s, done.
# Resolving deltas: 100% (90/90), done.
# Checking out files: 100% (42/42), done.

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 5.1 MB/s
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.1)
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 50.2 MB/s
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.21-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 503 kB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.4.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2018.9)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.21 geopandas-0.10.2 munch-2.5.0 pyproj-3.2.1

# %%
# load packages
import pandas as pd
import numpy as np
import os # for navigating directories
import requests # for API pull 
import geopandas as gpd

# %%
# navigate into the directory
os.chdir("cdc_vitalsigns")

# %% [markdown]
# ## Pull from APIs

# %%
# api info 
# read list of indicators 
api_df = pd.read_csv("archive/VS-Indicator-APIs_EF.csv") # new version - I've labeled which API calls to make under 'pull'
api_df.set_index("ShortName", inplace=True, drop = False) # drop = False I want ShortName as a column 
# add column for indicator name (used in my own data)
api_df["indicator"] = [string.replace("XX","") if type(string) == str else None for string in api_df.ShortName ]
# get full list of indicators we indend to pull
full_indicator_list = set(api_df[api_df.pull == 1].indicator)
api_df.head()
# Out:
#            Indicator Number  ... indicator
# ShortName                    ...
# tpopXX                    1  ...      tpop
# maleXX                    2  ...      male
# femaleXX                  3  ...    female
# paaXX                     4  ...       paa
# pwhiteXX                  5  ...    pwhite
#
# [5 rows x 7 columns]

# %%
# making use of previously created functions
def getGDFfromURL(url, layer=0):
    #GDF stands for GeoDataFrame; this is the innermost function called by getGDF
    tail = "/"+str(layer)+"/query?where=1%3D1&outFields=*&outSR=4326&f=json" #worked this out
    url+=tail
    print(url)
    # EF edits - for error handling in large batches
    try: 
      gdf = gpd.read_file(url) #GeoPandas has a built in function to read APIs given right URL
    except: 
      gdf = pd.DataFrame()
    return gdf

def getGDF(shortname, level=0):
    #This is outermost function called by user; it calls getGDFfromURL
    url = api_df.loc[shortname, "API"]
    return getGDFfromURL(url, level)

def getCollect(check_list, level = 0): # slight edit: I added level to this function 
    #This function collects all the target GDFs and puts into collection
    collect=[]
    for shortname in check_list:
        gdf=getGDF(shortname, level)
        collect.append(gdf)    
    return collect

# %% [markdown]
# #### Pulling new CSA-level values

# %%
### which indicators are new to pull? 

# get list of indicators that already exist in the data 
existing_df = pd.read_csv("full_vital_signs.csv")
# identify the new ones
new_indicators = full_indicator_list - set(existing_df.indicator)
# but now we need the shortnames again 
new_indicator_shortnames = list(api_df[api_df.indicator.isin(new_indicators)].ShortName)

# %%
# % driving alone is broken. Looking at the API url, it's an error 400
new_indicator_shortnames[21]
api_df.loc['drvaloneXX', "API"]
getGDF('drvaloneXX', level=0)
# Out:
# 'https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Dralone/FeatureServer'

# %%
### make API pull
# pull in segments so that I can isolate errors 
collect_new_1 = getCollect(new_indicator_shortnames[:21])
# FOUND ERROR in new_indicator_shortnames[21] ('drvaloneXX')
collect_new_2 = getCollect(new_indicator_shortnames[22:])
# Out:
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Cashsa/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Taxlien/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Demper/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Histax/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Homtax/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Owntax/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Nomail/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Mort14_/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Mort24_/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Mort44_/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Mort64_/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Mort84_/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Mort85_/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Publart/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Artbus/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Artemp/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Wrkout/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Smlinvst/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Neiind/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Neibus/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Neiemp/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Carpool/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Trav14_/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Trav29_/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Trav44_/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Trav45_/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Waterc/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Weather/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Eenrol/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Menrol/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hsenrol/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Treeplnt/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Cebus/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Ceemp/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Murals/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Totjobs/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Lights/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json

# %%
# turn the collections into dataframes 
df1 = pd.concat(collect_new_1)
df2 = pd.concat(collect_new_2)
# one full dataframe 
new_indicator_df = df1.append(df2)
new_indicator_df.head()
# Out:
#    OBJECTID                            CSA2010  ...  lights19  lights20
# 0       1.0      Allendale/Irvington/S. Hilton  ...       NaN       NaN
# 1       2.0    Beechfield/Ten Hills/West Hills  ...       NaN       NaN
# 2       3.0                      Belair-Edison  ...       NaN       NaN
# 3       4.0  Brooklyn/Curtis Bay/Hawkins Point  ...       NaN       NaN
# 4       5.0                             Canton  ...       NaN       NaN
#
# [5 rows x 315 columns]

# %%
### reformat data 
# drop geometry and objectID
#new_indicator_df = new_indicator_df.drop(['OBJECTID','Shape__Area', 'Shape__Length', "geometry"], axis = 1)
# melt (pivot longer)
new_indicator_melted = new_indicator_df.melt(id_vars = ["CSA2010"], 
                                  var_name = "year-indicator", 
                                  value_name = "value")
# drop NAs (a result of simply appending everything together)
new_indicator_melted.dropna(subset = ["value"], inplace = True)
# drop a strange value (indicator = 'City', value = 'Baltimore City')
new_indicator_melted = new_indicator_melted[new_indicator_melted.value != "Baltimore City"]
# add year column 
new_indicator_melted["year"] = ['20' + i[-2:] for i in new_indicator_melted['year-indicator']]
new_indicator_melted["year_numeric"] = [int(y) for y in new_indicator_melted.year]
# add column for indicator 
new_indicator_melted["indicator"] = [i[:-2] for i in new_indicator_melted["year-indicator"]]
# drop indicator-year field 
new_indicator_melted = new_indicator_melted.drop(["year-indicator"], axis = 1)

# pivot
new_indicator_melted
# Out:
#                                   CSA2010      value  ... year_numeric  indicator
# 0           Allendale/Irvington/S. Hilton      78.22  ...         2011     cashsa
# 1         Beechfield/Ten Hills/West Hills      32.05  ...         2011     cashsa
# 2                           Belair-Edison      66.67  ...         2011     cashsa
# 3       Brooklyn/Curtis Bay/Hawkins Point       73.4  ...         2011     cashsa
# 4                                  Canton      26.64  ...         2011     cashsa
# ...                                   ...        ...  ...          ...        ...
# 614105                Southwest Baltimore  24.322058  ...         2020     lights
# 614106                      The Waverlies  23.990713  ...         2020     lights
# 614107                Upton/Druid Heights  13.923806  ...         2020     lights
# 614108         Washington Village/Pigtown  32.164274  ...         2020     lights
# 614109     Westport/Mount Winans/Lakeland  14.608793  ...         2020     lights
#
# [16985 rows x 5 columns]

# %%
# troubleshooting 
set(new_indicator_melted[new_indicator_melted.year == '20ty']["year-indicator"])
new_indicator_melted[(new_indicator_melted.year == '20ty')]
# Out:
#        CSA2010 year-indicator           value  year
# 272277     NaN           City  Baltimore City  20ty

# %%
### combining existing and new DF 
# PLACEHOLDER FOR NOW

# %% [markdown]
# #### Pulling Baltimore City values

# %%
## using the full list of indicators, run the APIs to collect baltimore data 

# get shortnames 
full_indicator_shortnames = list(api_df[api_df.indicator.isin(full_indicator_list)].ShortName)
# pull in segments to isolate errors
collect_balt_1 = getCollect(full_indicator_shortnames[:51], level = 1)
# Out:
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Tpop/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Male/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Female/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Paa/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Pwhite/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Pasi/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/P2more/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Ppac/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Phisp/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Racdiv/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Age5_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Age18_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Age24_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Age64_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Age65_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hhs/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Femhhs/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Fam/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hhsize/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Mhhi/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hh25inc/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hh40inc/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hh60inc/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hh75inc/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hhm75/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hhpov/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hhchpov/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Salepr/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Dom/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Shomes/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Ownroc/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Fore/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Vacant/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Vio/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Resrehab/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Totalres/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Cashsa/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Reosa/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Taxlien/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Demper/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Constper/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Baltvac/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Affordm/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Affordr/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Histax/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Homtax/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Owntax/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Nomail/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Crime/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Viol/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Prop/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json

# %%
# errors
full_indicator_shortnames[51] # url: https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Domvio/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# URL returns error 400
full_indicator_shortnames[52] # url: https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Juvarr/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
full_indicator_shortnames[53] # url: https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Juvviol/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
full_indicator_shortnames[54] # url: https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Juvdrug/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
full_indicator_shortnames[69] # url: https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Susp/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
full_indicator_shortnames[70] # url: https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Farms/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
full_indicator_shortnames[71] # url: https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Sped/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
full_indicator_shortnames[72] # url: https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Ready/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
full_indicator_shortnames[73] # url: https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Math3/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
full_indicator_shortnames[74:83]
full_indicator_shortnames[97:104]
# there are a lot of errors, I implemented error handling and stopped manually tracking
# Out:
# 'suspXX'

# %%
collect_balt_2 = getCollect(full_indicator_shortnames[55:69], level = 1)
collect_balt_3 = getCollect(full_indicator_shortnames[83:97], level = 1)
collect_balt_4 = getCollect(full_indicator_shortnames[104:115], level = 1)
# after implementing a try/except clause in the API function.... we can just let it run in one batch now and return whatever results it can find 
collect_balt_5 = getCollect(full_indicator_shortnames[115:], level = 1)
# Out:
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Overd/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Libcard/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Artevnt/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Publart/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Artbus/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Artemp/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Empl/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Unempl/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Nilf/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Unempr/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Lesshs/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hsdipl/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Bahigher/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Comprop/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Crehab/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Numbus/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Totemp/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Smlbus/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Wrkout/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Smlinvst/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Banks/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Biz1_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Biz2_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Biz4_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Prbprl/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Nohhint/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Neiind/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Neibus/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Neiemp/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Regvote/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Voted/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Dirtyst/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Clogged/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Dralone/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Carpool/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Pubtran/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Walked/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Trav14_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Trav29_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Trav44_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Trav45_/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Trees/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Cmos/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Waterc/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Heatgas/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Elheat/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Novhcl/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Weather/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Wlksc/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Busload/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Bkln/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Othercom/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Eenrol/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Menrol/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hsenrol/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hfai/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Treeplnt/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Hcvhouse/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Cebus/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Ceemp/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Murals/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Totjobs/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Arrests/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Pmath3/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Pread3/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Pmath5/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Pread5/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Pmath8/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Pread8/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Palg1/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Palg2/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Kra/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
# https://services1.arcgis.com/mVFRs7NF4iFitgbY/arcgis/rest/services/Lights/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json
